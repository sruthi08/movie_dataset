# %% [markdown]
# - The movie dataset https://www.kaggle.com/rounakbanik/the-movies-dataset

# %% [markdown]
# - submitted by : Rama Sruthi Thulasiraman

# %% [markdown]
# ## First lets Load the data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movie_data = pd.read_csv('movies_metadata.csv')
# Out:
# /Users/sruthiraam/opt/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movie_data
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      False                                                NaN  60000000
# 6      False                                                NaN  58000000
# 7      False                                                NaN         0
# 8      False                                                NaN  35000000
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10     False                                                NaN  62000000
# 11     False                                                NaN         0
# ...

# %%
ratings = pd.read_csv('ratings_small.csv')

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# 5            1     1263     2.0  1260759151
# 6            1     1287     2.0  1260759187
# 7            1     1293     2.0  1260759148
# 8            1     1339     3.5  1260759125
# 9            1     1343     2.0  1260759131
# 10           1     1371     2.5  1260759135
# 11           1     1405     1.0  1260759203
# 12           1     1953     4.0  1260759191
# 13           1     2105     4.0  1260759139
# 14           1     2150     3.0  1260759194
# 15           1     2193     2.0  1260759198
# 16           1     2294     2.0  1260759108
# 17           1     2455     2.5  1260759113
# 18           1     2968     1.0  1260759200
# 19           1     3671     3.0  1260759117
# ...

# %% [markdown]
# ## Now lets focus on movie id's and movie title

# %%
movie_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie_data.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
# adult                    45466 non-null object
# belongs_to_collection    4494 non-null object
# budget                   45466 non-null object
# genres                   45466 non-null object
# homepage                 7782 non-null object
# id                       45466 non-null object
# imdb_id                  45449 non-null object
# original_language        45455 non-null object
# original_title           45466 non-null object
# overview                 44512 non-null object
# popularity               45461 non-null object
# poster_path              45080 non-null object
# production_companies     45463 non-null object
# production_countries     45463 non-null object
# release_date             45379 non-null object
# revenue                  45460 non-null float64
# runtime                  45203 non-null float64
# spoken_languages         45460 non-null object
# ...

# %% [markdown]
# ## missing values

# %%
movie_data.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ## Distribution

# %%
movie_data.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# ## For movie_id

# %%
movie_data.id.describe()
# Out:
# count      45466
# unique     45436
# top       141971
# freq           3
# Name: id, dtype: object

# %%
movie_data.imdb_id.describe()
# Out:
# count         45449
# unique        45417
# top       tt1180333
# freq              3
# Name: imdb_id, dtype: object

# %%
movie_data['id'].value_counts()
# Out:
# 141971    3
# 110428    2
# 168538    2
# 42495     2
# 119916    2
# 15028     2
# 5511      2
# 265189    2
# 77221     2
# 84198     2
# 109962    2
# 10991     2
# 4912      2
# 152795    2
# 18440     2
# 13209     2
# 132641    2
# 14788     2
# 23305     2
# 97995     2
# 298721    2
# 159849    2
# 22649     2
# 69234     2
# 12600     2
# 105045    2
# 25541     2
# 11115     2
# 99080     2
# 60141     1
#          ..
# 5491      1
# 104931    1
# 14201     1
# 82631     1
# 14202     1
# 3309      1
# 62753     1
# 424488    1
# 400411    1
# 41630     1
# 136795    1
# 41636     1
# 324284    1
# 354818    1
# 136799    1
# 34933     1
# 136793    1
# 147415    1
# 136797    1
# 232175    1
# 36606     1
# 83899     1
# 123858    1
# 102195    1
# 36600     1
# 83896     1
# 83897     1
# 83890     1
# 36607     1
# 262789    1
# Name: id, Length: 45436, dtype: int64

# %%
print(movie_data[['id','imdb_id']][:10])
# Out:
#       id    imdb_id
# 0    862  tt0114709
# 1   8844  tt0113497
# 2  15602  tt0113228
# 3  31357  tt0114885
# 4  11862  tt0113041
# 5    949  tt0113277
# 6  11860  tt0114319
# 7  45325  tt0112302
# 8   9091  tt0114576
# 9    710  tt0113189

# %% [markdown]
# ## For movie_title

# %%
movie_data.original_title.describe()
# Out:
# count      45466
# unique     43373
# top       Hamlet
# freq           8
# Name: original_title, dtype: object

# %%
movie_data['original_title'].value_counts()
# Out:
# Hamlet                              8
# Alice in Wonderland                 8
# The Three Musketeers                7
# Cinderella                          7
# Les Misérables                      7
# A Christmas Carol                   7
# Macbeth                             7
# The Hound of the Baskervilles       6
# Jane Eyre                           6
# Frankenstein                        6
# Treasure Island                     6
# Heidi                               6
# Wuthering Heights                   6
# King Lear                           6
# Blackout                            6
# Cleopatra                           5
# Great Expectations                  5
# Peter Pan                           5
# Beauty and the Beast                5
# Home                                5
# Emma                                5
# Eden                                5
# Aschenputtel                        4
# Jack and the Beanstalk              4
# Carmen                              4
# ...

# %%
print(movie_data[['original_title']][:10])
# Out:
#                 original_title
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
# 5                         Heat
# 6                      Sabrina
# 7                 Tom and Huck
# 8                 Sudden Death
# 9                    GoldenEye

# %%
print(movie_data['original_title'].isnull().value_counts())
# Out:
# False    45466
# Name: original_title, dtype: int64

# %% [markdown]
# ## Movie Id's and Title

# %%
print(movie_data[['id','original_title']])
# Out:
#            id                     original_title
# 0         862                          Toy Story
# 1        8844                            Jumanji
# 2       15602                   Grumpier Old Men
# 3       31357                  Waiting to Exhale
# 4       11862        Father of the Bride Part II
# 5         949                               Heat
# 6       11860                            Sabrina
# 7       45325                       Tom and Huck
# 8        9091                       Sudden Death
# 9         710                          GoldenEye
# 10       9087             The American President
# 11      12110        Dracula: Dead and Loving It
# 12      21032                              Balto
# 13      10858                              Nixon
# 14       1408                   Cutthroat Island
# 15        524                             Casino
# 16       4584              Sense and Sensibility
# 17          5                         Four Rooms
# ...

# %% [markdown]
# ## Ratings

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100004.000000  100004.000000  100004.000000  1.000040e+05
# mean      347.011310   12548.664363       3.543608  1.129639e+09
# std       195.163838   26369.198969       1.058064  1.916858e+08
# min         1.000000       1.000000       0.500000  7.896520e+08
# 25%       182.000000    1028.000000       3.000000  9.658478e+08
# 50%       367.000000    2406.500000       4.000000  1.110422e+09
# 75%       520.000000    5418.000000       4.000000  1.296192e+09
# max       671.000000  163949.000000       5.000000  1.476641e+09

# %%
ratings.rating.describe()
# Out:
# count    100004.000000
# mean          3.543608
# std           1.058064
# min           0.500000
# 25%           3.000000
# 50%           4.000000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64

# %%
ratings['rating'].value_counts()
# Out:
# 4.0    28750
# 3.0    20064
# 5.0    15095
# 3.5    10538
# 4.5     7723
# 2.0     7271
# 2.5     4449
# 1.0     3326
# 1.5     1687
# 0.5     1101
# Name: rating, dtype: int64

# %%
print(ratings[['rating']][:10])
# Out:
#    rating
# 0     2.5
# 1     3.0
# 2     3.0
# 3     2.0
# 4     4.0
# 5     2.0
# 6     2.0
# 7     2.0
# 8     3.5
# 9     2.0

# %%
print(ratings['rating'].isnull().value_counts())
# Out:
# False    100004
# Name: rating, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.distplot(ratings.rating)

# %%
ratings['rating'].value_counts(sort=False).plot(kind='bar')
